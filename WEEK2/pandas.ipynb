# %%
import pandas as pd
import numpy as np
s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print("\nSeries:")
print(s)

# Create a DataFrame (2D labeled table)
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'Salary': [50000, 60000, 70000, 80000]
}
df = pd.DataFrame(data)
print("\nDataFrame:")
print(df)
# Out:
# Series:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
#
# DataFrame:
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   70000
# 3    David   40   80000

# %%
import pandas as pd
import numpy as np
array = np.array([[1, 2], [3, 4], [5, 6]])
df_from_array = pd.DataFrame(array, columns=['Column1', 'Column2'])
print("\nDataFrame from NumPy array:")
print(df_from_array)
# Out:
# DataFrame from NumPy array:
#    Column1  Column2
# 0        1        2
# 1        3        4
# 2        5        6

# %%
print("\nRow with label 1 using loc:")
print(df.loc[1])
# Out:
# Row with label 1 using loc:
# Name        Bob
# Age          30
# Salary    60000
# Name: 1, dtype: object

# %%
print("\nFirst two rows using iloc:")
print(df.iloc[0:2])
# Out:
# First two rows using iloc:
#     Name  Age  Salary
# 0  Alice   25   50000
# 1    Bob   30   60000

# %%
print("\nSelect 'Name' column:")
print(df['Name'])

# Select multiple columns
print("\nSelect 'Name' and 'Age' columns:")
print(df[['Name', 'Age']])

# Filter rows where a condition is true
print("\nRows where Salary > 60000:")
print(df[df['Salary'] > 60000])
# Out:
# Select 'Name' column:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: object
#
# Select 'Name' and 'Age' columns:
#       Name  Age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35
# 3    David   40
#
# Rows where Salary > 60000:
#       Name  Age  Salary
# 2  Charlie   35   70000
# 3    David   40   80000

# %%
data_dirty = {
    'Name': ['Alice', 'Bob', None, 'David'],
    'Age': [25, None, 35, 40],
    'Salary': [50000, 60000, None, 80000]
}
df_dirty = pd.DataFrame(data_dirty)
print("\nOriginal Dirty DataFrame:")
print(df_dirty)
# Out:
# Original Dirty DataFrame:
#     Name   Age   Salary
# 0  Alice  25.0  50000.0
# 1    Bob   NaN  60000.0
# 2   None  35.0      NaN
# 3  David  40.0  80000.0

# %%
print("\nDrop rows with any NaN values:")
print(df_dirty.dropna())

# Fill missing values with specified values
print("\nFill missing values with a specific value:")
print(df_dirty.fillna({'Name': 'Unknown', 'Age': df_dirty['Age'].mean(), 'Salary': 0}))
# Out:
# Drop rows with any NaN values:
#     Name   Age   Salary
# 0  Alice  25.0  50000.0
# 3  David  40.0  80000.0
#
# Fill missing values with a specific value:
#       Name        Age   Salary
# 0    Alice  25.000000  50000.0
# 1      Bob  33.333333  60000.0
# 2  Unknown  35.000000      0.0
# 3    David  40.000000  80000.0

# %%
import pandas as pd
import numpy as np
data_dirty = {
    'Name': ['Alice', 'Bob', None, 'David'],
    'Age': [25, None, 35, 40],
    'Salary': [50000, 60000, None, 80000]
}
df_dirty = pd.DataFrame(data_dirty)
# Detect missing values with a Boolean DataFrame
print("\nBoolean DataFrame for missing values:")

print(df_dirty.isnull())
# Out:
# Boolean DataFrame for missing values:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2   True  False    True
# 3  False  False   False

# %%
import pandas as pd
import numpy as np
data_dirty = {
    'Name': ['Alice', 'Bob', None, 'David'],
    'Age': [25, None, 35, 40],
    'Salary': [50000, 60000, None, 80000]
}
df_dirty = pd.DataFrame(data_dirty)
# Add a new column based on calculations
df_dirty['Bonus'] = df_dirty['Salary'] * 0.1
print("\nDataFrame with Bonus column:")
print(df_dirty)

# Rename columns using rename()
print("\nRename columns:")
df_renamed = df_dirty.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)

# Sort rows by a column in descending order
print("\nSort by Age descending:")
print(df_dirty.sort_values(by='Age', ascending=False))

# Group by a derived boolean column and calculate mean
print("\nGroup by operation (average salary by age > 30 or not):")
df_dirty['AgeGroup'] = df_dirty['Age'] > 30
print(df_dirty.groupby('AgeGroup')['Salary'].mean())
# Out:
# DataFrame with Bonus column:
#     Name   Age   Salary   Bonus
# 0  Alice  25.0  50000.0  5000.0
# 1    Bob   NaN  60000.0  6000.0
# 2   None  35.0      NaN     NaN
# 3  David  40.0  80000.0  8000.0
#
# Rename columns:
#     Name   Age  BaseSalary   Bonus
# 0  Alice  25.0     50000.0  5000.0
# 1    Bob   NaN     60000.0  6000.0
# 2   None  35.0         NaN     NaN
# 3  David  40.0     80000.0  8000.0
#
# Sort by Age descending:
#     Name   Age   Salary   Bonus
# 3  David  40.0  80000.0  8000.0
# 2   None  35.0      NaN     NaN
# 0  Alice  25.0  50000.0  5000.0
# 1    Bob   NaN  60000.0  6000.0
#
# Group by operation (average salary by age > 30 or not):
# AgeGroup
# False    55000.0
# True     80000.0
# Name: Salary, dtype: float64

# %%
import pandas as pd
import numpy as np
data_dirty = {
    'Name': ['Alice', 'Bob', None, 'David'],
    'Age': [25, None, 35, 40],
    'Salary': [50000, 60000, None, 80000]
}
df_dirty = pd.DataFrame(data_dirty)
# Rename columns using rename()
print("\nRename columns:")
df_dirty_renamed = df_dirty.rename(columns={'Salary': 'BaseSalary'})
print(df_renamed)
# Out:
# Rename columns:
#     Name   Age  BaseSalary   Bonus
# 0  Alice  25.0     50000.0  5000.0
# 1    Bob   NaN     60000.0  6000.0
# 2   None  35.0         NaN     NaN
# 3  David  40.0     80000.0  8000.0

# %%
# Sort rows by a column in descending order
print("\nSort by Age descending:")
print(df_dirty.sort_values(by='Age', ascending=False))

# Group by a derived boolean column and calculate mean
print("\nGroup by operation (average salary by age > 30 or not):")
df_dirty['AgeGroup'] = df_dirty['Age'] > 30
print(df_dirty.groupby('AgeGroup')['Salary'].mean())
# Out:
# Sort by Age descending:
#     Name   Age   Salary
# 3  David  40.0  80000.0
# 2   None  35.0      NaN
# 0  Alice  25.0  50000.0
# 1    Bob   NaN  60000.0
#
# Group by operation (average salary by age > 30 or not):
# AgeGroup
# False    55000.0
# True     80000.0
# Name: Salary, dtype: float64

# %%
# Create a synthetic DataFrame for practice with random data
np.random.seed(1)
num_rows = 10
df_synth = pd.DataFrame({
    'ID': np.arange(1, num_rows + 1),
    'Score': np.random.randint(50, 100, size=num_rows),
    'Passed': np.random.choice([True, False], size=num_rows)
})

print("\nSynthetic DataFrame:")
print(df_synth)
# Out:
# Synthetic DataFrame:
#    ID  Score  Passed
# 0   1     87   False
# 1   2     93    True
# 2   3     62   False
# 3   4     58   False
# 4   5     59    True
# 5   6     61    True
# 6   7     55   False
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True

# %%
# Filter rows based on a condition
print("\nStudents who passed:")
print(df_synth[df_synth['Passed'] == True])

# Calculate mean for filtered rows
print("\nAverage score of failed students:")
print(df_synth[df_synth['Passed'] == False]['Score'].mean())
# Out:
# Students who passed:
#    ID  Score  Passed
# 1   2     93    True
# 4   5     59    True
# 5   6     61    True
# 7   8     65    True
# 8   9     50    True
# 9  10     66    True
#
# Average score of failed students:
# 65.5

# %%
# -----------------------------------------------------------
# 🔹 7. INSPECTING DATAFRAME STRUCTURE
# -----------------------------------------------------------

# Get concise summary of DataFrame including types and non-null counts
print("\nDataFrame info:")
df_dirty.info()

# Get basic statistics of numerical columns
print("\nDataFrame describe:")
print(df_dirty.describe())
# Out:
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      3 non-null      object
#  1   Age       3 non-null      float64
#  2   Salary    3 non-null      float64
#  3   AgeGroup  4 non-null      bool
# dtypes: bool(1), float64(2), object(1)
# memory usage: 232.0+ bytes
#
# DataFrame describe:
#              Age        Salary
# count   3.000000      3.000000
# mean   33.333333  63333.333333
# std     7.637626  15275.252317
# min    25.000000  50000.000000
# 25%    30.000000  55000.000000
# 50%    35.000000  60000.000000
# 75%    37.500000  70000.000000
# max    40.000000  80000.000000

# %%
# Check data types of columns
print("\nData types of each column:")
print(df_dirty.dtypes)

# View top rows
print("\nFirst 3 rows:")
print(df_dirty.head(3))

# View bottom rows
print("\nLast 2 rows:")
print(df_dirty.tail(2))
# Out:
# Data types of each column:
# Name         object
# Age         float64
# Salary      float64
# AgeGroup       bool
# dtype: object
#
# First 3 rows:
#     Name   Age   Salary  AgeGroup
# 0  Alice  25.0  50000.0     False
# 1    Bob   NaN  60000.0     False
# 2   None  35.0      NaN      True
#
# Last 2 rows:
#     Name   Age   Salary  AgeGroup
# 2   None  35.0      NaN      True
# 3  David  40.0  80000.0      True

# %%
df_dirty['Bonus'] = df_dirty['Salary'] * 0.1
# -----------------------------------------------------------
# 🔹 8. STATISTICAL & PROBABILITY FUNCTIONS IN PANDAS
# -----------------------------------------------------------

# Compute central tendency measures
print("\nMean Age:", df_dirty['Age'].mean())
print("Median Salary:", df_dirty['Salary'].median())
print("Mode of Bonus:")
print(df_dirty['Bonus'].mode())

# Compute spread measures
print("Standard Deviation of Salary:", df_dirty['Salary'].std())
print("Variance of Salary:", df_dirty['Salary'].var())
# Out:
# Mean Age: 33.333333333333336
# Median Salary: 60000.0
# Mode of Bonus:
# 0    5000.0
# 1    6000.0
# 2    8000.0
# Name: Bonus, dtype: float64
# Standard Deviation of Salary: 15275.252316519465
# Variance of Salary: 233333333.3333333

# %%
# Correlation and Covariance between columns
print("\nCorrelation between Age and Salary:")
print(df_dirty[['Age', 'Salary']].corr())

print("\nCovariance between Age and Salary:")
print(df_dirty[['Age', 'Salary']].cov())

# Frequency of values
print("\nValue counts for AgeGroup:")
print(df_dirty['AgeGroup'].value_counts())
# Out:
# Correlation between Age and Salary:
#         Age  Salary
# Age     1.0     1.0
# Salary  1.0     1.0
#
# Covariance between Age and Salary:
#                   Age        Salary
# Age         58.333333  2.250000e+05
# Salary  225000.000000  2.333333e+08
#
# Value counts for AgeGroup:
# AgeGroup
# False    2
# True     2
# Name: count, dtype: int64

# %%
# Cumulative statistics
print("\nCumulative sum of Salary:")
print(df_dirty['Salary'].cumsum())

print("\nCumulative max of Salary:")
print(df_dirty['Salary'].cummax())

# Rank values
print("\nRank of Salary:")
print(df_dirty['Salary'].rank())

# Quantile-based binning
print("\nQuantiles of Salary:")
print(df_dirty['Salary'].quantile([0.25, 0.5, 0.75]))
# Out:
# Cumulative sum of Salary:
# 0     50000.0
# 1    110000.0
# 2         NaN
# 3    190000.0
# Name: Salary, dtype: float64
#
# Cumulative max of Salary:
# 0    50000.0
# 1    60000.0
# 2        NaN
# 3    80000.0
# Name: Salary, dtype: float64
#
# Rank of Salary:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    3.0
# Name: Salary, dtype: float64
#
# Quantiles of Salary:
# 0.25    55000.0
# 0.50    60000.0
# 0.75    70000.0
# Name: Salary, dtype: float64

# %%
# -----------------------------------------------------------
# 🔹 END OF PANDAS PRACTICAL
# -----------------------------------------------------------

# -----------------------------------------------------------
# 📊 SUMMARY TABLE: Important Pandas Functions
# -----------------------------------------------------------
import pandas as pd

summary_data = {
    "Function": [
        "pd.Series()",
        "pd.DataFrame()",
        "df.head()",
        "df.tail()",
        "df.info()",
        "df.describe()",
        "df.dtypes",
        "df.loc[]",
        "df.iloc[]",
        "df['column']",
        "df[['col1','col2']]",
        "df.dropna()",
        "df.fillna()",
        "df.isnull()",
        "df.sort_values()",
        "df.groupby()",
        "df.mean(), median(), mode()",
        "df.std(), var()",
        "df.corr(), cov()",
        "df.value_counts()",
        "df.cumsum(), cummax()",
        "df.rank()",
        "df.quantile()",
        "pd.read_csv()",
        "pd.read_excel()",
        "pd.read_json()"
    ],
    "Purpose": [
        "Create a one-dimensional labeled array",
        "Create a 2D labeled data structure",
        "Display first n rows",
        "Display last n rows",
        "Summary including non-null values, types",
        "Statistical summary of numerical columns",
        "Data types of each column",
        "Label-based row/column selection",
        "Position-based row/column selection",
        "Select a single column",
        "Select multiple columns",
        "Remove rows with missing values",
        "Fill missing values",
        "Check for missing values",
        "Sort by column values",
        "Group data and apply aggregation",
        "Central tendency stats",
        "Spread or dispersion stats",
        "Relationships between columns",
        "Frequency of values",
        "Cumulative operations",
        "Ranks of data",
        "Get quantiles",
        "Read CSV file",
        "Read Excel file",
        "Read JSON file"
    ]
}

summary_df = pd.DataFrame(summary_data)
print("\nSummary of Important Pandas Functions:")
print(summary_df)

# -----------------------------------------------------------
# 🔹 END OF NOTEBOOK
# -----------------------------------------------------------
# Out:
# Summary of Important Pandas Functions:
#                        Function                                   Purpose
# 0                   pd.Series()    Create a one-dimensional labeled array
# 1                pd.DataFrame()        Create a 2D labeled data structure
# 2                     df.head()                      Display first n rows
# 3                     df.tail()                       Display last n rows
# 4                     df.info()  Summary including non-null values, types
# 5                 df.describe()  Statistical summary of numerical columns
# 6                     df.dtypes                 Data types of each column
# 7                      df.loc[]          Label-based row/column selection
# 8                     df.iloc[]       Position-based row/column selection
# 9                  df['column']                    Select a single column
# 10          df[['col1','col2']]                   Select multiple columns
# 11                  df.dropna()           Remove rows with missing values
# 12                  df.fillna()                       Fill missing values
# 13                  df.isnull()                  Check for missing values
# 14             df.sort_values()                     Sort by column values
# 15                 df.groupby()          Group data and apply aggregation
# 16  df.mean(), median(), mode()                    Central tendency stats
# 17              df.std(), var()                Spread or dispersion stats
# 18             df.corr(), cov()             Relationships between columns
# 19            df.value_counts()                       Frequency of values
# 20        df.cumsum(), cummax()                     Cumulative operations
# 21                    df.rank()                             Ranks of data
# 22                df.quantile()                             Get quantiles
# 23                pd.read_csv()                             Read CSV file
# 24              pd.read_excel()                           Read Excel file
# 25               pd.read_json()                            Read JSON file
