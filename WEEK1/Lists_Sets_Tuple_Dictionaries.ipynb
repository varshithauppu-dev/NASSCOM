# %%
fruits = ['Mango', 'Guava', 'Dragon', 'Watermelon']
print("List of Fruits:", fruits)
print("First First:", fruits[0])
# Out:
# List of Fruits: ['Mango', 'Guava', 'Dragon', 'Watermelon']
# First First: Mango

# %%
fruits = ['Mango', 'Guava', 'Dragon', 'Watermelon']
fruits.append('orange')
print("After appending:", fruits)
# Out:
# After appending: ['Mango', 'Guava', 'Dragon', 'Watermelon', 'orange']

# %%
fruits = ['Mango', 'Guava', 'banana', 'Watermelon']
fruits.remove('banana')
print("After removing banana:", fruits)

# List length
print("Number of fruits:", len(fruits))
# Out:
# After removing banana: ['Mango', 'Guava', 'Watermelon']
# Number of fruits: 3

# %%
#TUPLES
dimensions = (10, 20, 30)
print("Tuple:", dimensions)
# Out:
# Tuple: (10, 20, 30)

# %%
dimensions = (10, 20, 30)
print("Second element:", dimensions[1])
# Out:
# Second element: 20

# %%
unique_numbers = {1, 2, 3, 2, 1}
print("Set (no duplicates):", unique_numbers)
# Out:
# Set (no duplicates): {1, 2, 3}

# %%
unique_numbers = {1, 2, 3, 2, 1}
unique_numbers.add(4)
print("After adding 4:", unique_numbers)
# Out:
# After adding 4: {1, 2, 3, 4}

# %%
unique_numbers = {1, 2, 3, 2, 1}
unique_numbers.remove(2)
print("After removing 2:", unique_numbers)
# Out:
# After removing 2: {1, 3}

# %%
set_a = {1, 2, 3}
set_b = {3, 4, 5}
print("Union:", set_a | set_b)
print("Intersection:", set_a & set_b)
print("Difference (A - B):", set_a - set_b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference (A - B): {1, 2}

# %%
student = {
    'name': 'Python',
    'age': 210,
    'course': 'P'
}
print("Dictionary:", student)
# Out:
# Dictionary: {'name': 'Python', 'age': 210, 'course': 'P'}

# %%
student = {
    'name': 'Alice',
    'age': 21,
    'course': 'Python'
}
print("Student name:", student['name'])
# Out:
# Student name: Alice

# %%
student['grade'] = 'A'
print("After adding grade:", student)

# Remove a key
del student['age']
print("After deleting age:", student)

# Loop through dictionary
for key, value in student.items():
    print(f"{key}: {value}")
# Out:
# After adding grade: {'name': 'Alice', 'age': 21, 'course': 'Python', 'grade': 'A'}
# After deleting age: {'name': 'Alice', 'course': 'Python', 'grade': 'A'}
# name: Alice
# course: Python
# grade: A

# %%
keys = ['id', 'name', 'marks']
values = [5, 'Sushanth', 98]
student_info = dict(zip(keys, values))
print("Student Info from zip:", student_info)
# Out:
# Student Info from zip: {'id': 5, 'name': 'Sushanth', 'marks': 98}
